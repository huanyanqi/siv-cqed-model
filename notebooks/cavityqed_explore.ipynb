# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit, minimize

from sivqed.models.siv import SiV
from sivqed.models.cavity import Cavity, CavitySiV

plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = [8, 5]

# %%
w_arr = np.linspace(-50, 50, 1000)

# %%
c = Cavity({"w_c" : 0, "k_in" : 30, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 6.2, "gamma_up" : 0.1})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 30, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 2.2, "gamma_up" : 0.5})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 30, "k_tot" : 50}, 
           {"w_up" : 15., "g_up" : 2.2, "gamma_up" : 0.5})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 20, "k_tot" : 50}, 
           {"w_up" : 10., "g_up" : 2.2, "gamma_up" : 0.5})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 10, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 2.2, "gamma_up" : 0.1})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 40, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 2.2, "gamma_up" : 0.1})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 10, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 6.2, "gamma_up" : 0.1})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
c = Cavity({"w_c" : 0, "k_in" : 40, "k_tot" : 50}, 
           {"w_up" : 0., "g_up" : 6.2, "gamma_up" : 0.1})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# # Temp

# %%
c = Cavity({"w_c" : -32, "k_in" : 35, "k_tot" : 159}, 
           {"w_up" : 5., "g_up" : 7.7, "gamma_up" : 0.000001})
plt.plot(w_arr, c.reflectance(w_arr, -1), label="empty")
plt.plot(w_arr, c.reflectance(w_arr, 1), label="up")
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)
